# %%
import coremltools
from coremltools.proto import FeatureTypes_pb2
from src.datasets import camvid
from src.tiramisu import tiramisu
# Out:
# WARNING:root:TensorFlow version 1.10.1 detected. Last version known to be fully compatible is 1.5.0 .

# %% [markdown]
# # Model

# %%
# load the dataset to get the output shape information
camvid11 = camvid.CamVid(mapping=camvid.CamVid.load_mapping(), ignored_labels=['Void'])
# build the model for the image shape and number of labels
model = tiramisu.tiramisu((352, 480, 3), camvid11.n,
    class_weights=camvid11.class_mask,
    growth_rate=12,
    layer_sizes=[3, 3, 3, 3, 3],
    bottleneck_size=3,
)
model.load_weights('models/Tiramisu45-CityScapes.h5')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Tiramisu_input (InputLayer)     (None, 352, 480, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 352, 480, 48) 1344        Tiramisu_input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 352, 480, 48) 192         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 352, 480, 48) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 352, 480, 12) 5196        activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 352, 480, 12) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 352, 480, 60) 0           conv2d_1[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 352, 480, 60) 240         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 352, 480, 60) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 352, 480, 12) 6492        activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 352, 480, 12) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 352, 480, 72) 0           concatenate_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 352, 480, 72) 288         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 352, 480, 72) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 352, 480, 12) 7788        activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 352, 480, 12) 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 352, 480, 36) 0           dropout_1[0][0]
#                                                                  dropout_2[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 352, 480, 84) 0           conv2d_1[0][0]
#                                                                  concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 352, 480, 84) 336         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 352, 480, 84) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 352, 480, 84) 7140        activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 352, 480, 84) 0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 176, 240, 84) 0           dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 176, 240, 84) 336         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 176, 240, 84) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 176, 240, 12) 9084        activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 176, 240, 12) 0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 176, 240, 96) 0           max_pooling2d_1[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 176, 240, 96) 384         concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 176, 240, 96) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 176, 240, 12) 10380       activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 176, 240, 12) 0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 176, 240, 108 0           concatenate_5[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 176, 240, 108 432         concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 176, 240, 108 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 176, 240, 12) 11676       activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 176, 240, 12) 0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 176, 240, 36) 0           dropout_5[0][0]
#                                                                  dropout_6[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 176, 240, 120 0           max_pooling2d_1[0][0]
#                                                                  concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 176, 240, 120 480         concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 176, 240, 120 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 176, 240, 120 14520       activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 176, 240, 120 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 88, 120, 120) 0           dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 88, 120, 120) 480         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 88, 120, 120) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 88, 120, 12)  12972       activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 88, 120, 12)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 88, 120, 132) 0           max_pooling2d_2[0][0]
#                                                                  dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 88, 120, 132) 528         concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 88, 120, 132) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 88, 120, 12)  14268       activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 88, 120, 12)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 88, 120, 144) 0           concatenate_9[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 88, 120, 144) 576         concatenate_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 88, 120, 144) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 88, 120, 12)  15564       activation_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 88, 120, 12)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 88, 120, 36)  0           dropout_9[0][0]
#                                                                  dropout_10[0][0]
#                                                                  dropout_11[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 88, 120, 156) 0           max_pooling2d_2[0][0]
#                                                                  concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 88, 120, 156) 624         concatenate_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 88, 120, 156) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 88, 120, 156) 24492       activation_12[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 88, 120, 156) 0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 44, 60, 156)  0           dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 44, 60, 156)  624         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 44, 60, 156)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 44, 60, 12)   16860       activation_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 44, 60, 12)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 44, 60, 168)  0           max_pooling2d_3[0][0]
#                                                                  dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 44, 60, 168)  672         concatenate_13[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 44, 60, 168)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 44, 60, 12)   18156       activation_14[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 44, 60, 12)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 44, 60, 180)  0           concatenate_13[0][0]
#                                                                  dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 44, 60, 180)  720         concatenate_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 44, 60, 180)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 44, 60, 12)   19452       activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 44, 60, 12)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 44, 60, 36)   0           dropout_13[0][0]
#                                                                  dropout_14[0][0]
#                                                                  dropout_15[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 44, 60, 192)  0           max_pooling2d_3[0][0]
#                                                                  concatenate_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 44, 60, 192)  768         concatenate_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 44, 60, 192)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 44, 60, 192)  37056       activation_16[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 44, 60, 192)  0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 22, 30, 192)  0           dropout_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 22, 30, 192)  768         max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 22, 30, 192)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 22, 30, 12)   20748       activation_17[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 22, 30, 12)   0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 22, 30, 204)  0           max_pooling2d_4[0][0]
#                                                                  dropout_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 22, 30, 204)  816         concatenate_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 22, 30, 204)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 22, 30, 12)   22044       activation_18[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 22, 30, 12)   0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 22, 30, 216)  0           concatenate_17[0][0]
#                                                                  dropout_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 22, 30, 216)  864         concatenate_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 22, 30, 216)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 22, 30, 12)   23340       activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 22, 30, 12)   0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 22, 30, 36)   0           dropout_17[0][0]
#                                                                  dropout_18[0][0]
#                                                                  dropout_19[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 22, 30, 228)  0           max_pooling2d_4[0][0]
#                                                                  concatenate_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 22, 30, 228)  912         concatenate_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 22, 30, 228)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 22, 30, 228)  52212       activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 22, 30, 228)  0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 11, 15, 228)  0           dropout_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 11, 15, 228)  912         max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 11, 15, 228)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 11, 15, 12)   24636       activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 11, 15, 12)   0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 11, 15, 240)  0           max_pooling2d_5[0][0]
#                                                                  dropout_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 11, 15, 240)  960         concatenate_21[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 11, 15, 240)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 11, 15, 12)   25932       activation_22[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 11, 15, 12)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 11, 15, 252)  0           concatenate_21[0][0]
#                                                                  dropout_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 11, 15, 252)  1008        concatenate_22[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 11, 15, 252)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 11, 15, 12)   27228       activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 11, 15, 12)   0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 11, 15, 36)   0           dropout_21[0][0]
#                                                                  dropout_22[0][0]
#                                                                  dropout_23[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 22, 30, 36)   11700       concatenate_23[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 22, 30, 264)  0           conv2d_transpose_1[0][0]
#                                                                  concatenate_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 22, 30, 264)  1056        concatenate_24[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 22, 30, 264)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 22, 30, 12)   28524       activation_24[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 22, 30, 12)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 22, 30, 276)  0           concatenate_24[0][0]
#                                                                  dropout_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 22, 30, 276)  1104        concatenate_25[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 22, 30, 276)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 22, 30, 12)   29820       activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 22, 30, 12)   0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 22, 30, 288)  0           concatenate_25[0][0]
#                                                                  dropout_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 22, 30, 288)  1152        concatenate_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 22, 30, 288)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 22, 30, 12)   31116       activation_26[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 22, 30, 12)   0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 22, 30, 36)   0           dropout_24[0][0]
#                                                                  dropout_25[0][0]
#                                                                  dropout_26[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 44, 60, 36)   11700       concatenate_27[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 44, 60, 228)  0           conv2d_transpose_2[0][0]
#                                                                  concatenate_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 44, 60, 228)  912         concatenate_28[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 44, 60, 228)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 44, 60, 12)   24636       activation_27[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 44, 60, 12)   0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 44, 60, 240)  0           concatenate_28[0][0]
#                                                                  dropout_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 44, 60, 240)  960         concatenate_29[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 44, 60, 240)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 44, 60, 12)   25932       activation_28[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 44, 60, 12)   0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 44, 60, 252)  0           concatenate_29[0][0]
#                                                                  dropout_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 44, 60, 252)  1008        concatenate_30[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 44, 60, 252)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 44, 60, 12)   27228       activation_29[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 44, 60, 12)   0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 44, 60, 36)   0           dropout_27[0][0]
#                                                                  dropout_28[0][0]
#                                                                  dropout_29[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 88, 120, 36)  11700       concatenate_31[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 88, 120, 192) 0           conv2d_transpose_3[0][0]
#                                                                  concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 88, 120, 192) 768         concatenate_32[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 88, 120, 192) 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 88, 120, 12)  20748       activation_30[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 88, 120, 12)  0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 88, 120, 204) 0           concatenate_32[0][0]
#                                                                  dropout_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 88, 120, 204) 816         concatenate_33[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 88, 120, 204) 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 88, 120, 12)  22044       activation_31[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 88, 120, 12)  0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 88, 120, 216) 0           concatenate_33[0][0]
#                                                                  dropout_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 88, 120, 216) 864         concatenate_34[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 88, 120, 216) 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 88, 120, 12)  23340       activation_32[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 88, 120, 12)  0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 88, 120, 36)  0           dropout_30[0][0]
#                                                                  dropout_31[0][0]
#                                                                  dropout_32[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 176, 240, 36) 11700       concatenate_35[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 176, 240, 156 0           conv2d_transpose_4[0][0]
#                                                                  concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 176, 240, 156 624         concatenate_36[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 176, 240, 156 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 176, 240, 12) 16860       activation_33[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 176, 240, 12) 0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 176, 240, 168 0           concatenate_36[0][0]
#                                                                  dropout_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 176, 240, 168 672         concatenate_37[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 176, 240, 168 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 176, 240, 12) 18156       activation_34[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 176, 240, 12) 0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 176, 240, 180 0           concatenate_37[0][0]
#                                                                  dropout_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 176, 240, 180 720         concatenate_38[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 176, 240, 180 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 176, 240, 12) 19452       activation_35[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 176, 240, 12) 0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 176, 240, 36) 0           dropout_33[0][0]
#                                                                  dropout_34[0][0]
#                                                                  dropout_35[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 352, 480, 36) 11700       concatenate_39[0][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 352, 480, 120 0           conv2d_transpose_5[0][0]
#                                                                  concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 352, 480, 120 480         concatenate_40[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 352, 480, 120 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 352, 480, 12) 12972       activation_36[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 352, 480, 12) 0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# concatenate_41 (Concatenate)    (None, 352, 480, 132 0           concatenate_40[0][0]
#                                                                  dropout_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 352, 480, 132 528         concatenate_41[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 352, 480, 132 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 352, 480, 12) 14268       activation_37[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 352, 480, 12) 0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# concatenate_42 (Concatenate)    (None, 352, 480, 144 0           concatenate_41[0][0]
#                                                                  dropout_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 352, 480, 144 576         concatenate_42[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 352, 480, 144 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 352, 480, 12) 15564       activation_38[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 352, 480, 12) 0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# concatenate_43 (Concatenate)    (None, 352, 480, 36) 0           dropout_36[0][0]
#                                                                  dropout_37[0][0]
#                                                                  dropout_38[0][0]
# __________________________________________________________________________________________________
# logits (Conv2D)                 (None, 352, 480, 12) 444         concatenate_43[0][0]
# __________________________________________________________________________________________________
# softmax (Activation)            (None, 352, 480, 12) 0           logits[0][0]
# ==================================================================================================
# Total params: 844,344
# Trainable params: 831,264
# Non-trainable params: 13,080
# __________________________________________________________________________________________________

# %% [markdown]
# # CoreML Tools

# %%
coreml_model = coremltools.converters.keras.convert(model,
	input_names='image',
	image_input_names='image',
    output_names='segmentation',
	image_scale=1/255.0,
)
# Out:
# 0 : Tiramisu_input, <keras.engine.topology.InputLayer object at 0x123ee15f8>
# 1 : conv2d_1, <keras.layers.convolutional.Conv2D object at 0x123f10438>
# 2 : batch_normalization_1, <keras.layers.normalization.BatchNormalization object at 0x123f10550>
# 3 : activation_1, <keras.layers.core.Activation object at 0x123e3c710>
# 4 : conv2d_2, <keras.layers.convolutional.Conv2D object at 0x1149a7550>
# 5 : concatenate_1, <keras.layers.merge.Concatenate object at 0x123f4c588>
# 6 : batch_normalization_2, <keras.layers.normalization.BatchNormalization object at 0x123fb3a58>
# 7 : activation_2, <keras.layers.core.Activation object at 0x123fb3e48>
# 8 : conv2d_3, <keras.layers.convolutional.Conv2D object at 0x124039ba8>
# 9 : concatenate_2, <keras.layers.merge.Concatenate object at 0x1240b4400>
# 10 : batch_normalization_3, <keras.layers.normalization.BatchNormalization object at 0x1240b48d0>
# 11 : activation_3, <keras.layers.core.Activation object at 0x1240b47b8>
# 12 : conv2d_4, <keras.layers.convolutional.Conv2D object at 0x124143240>
# 13 : concatenate_3, <keras.layers.merge.Concatenate object at 0x1241a3898>
# 14 : concatenate_4, <keras.layers.merge.Concatenate object at 0x1241a3710>
# 15 : batch_normalization_4, <keras.layers.normalization.BatchNormalization object at 0x1241a3c50>
# 16 : activation_4, <keras.layers.core.Activation object at 0x12422d7f0>
# 17 : conv2d_5, <keras.layers.convolutional.Conv2D object at 0x12424e9e8>
# 18 : max_pooling2d_1, <keras.layers.pooling.MaxPooling2D object at 0x12428be80>
# 19 : batch_normalization_5, <keras.layers.normalization.BatchNormalization object at 0x1242b53c8>
# 20 : activation_5, <keras.layers.core.Activation object at 0x1242b5438>
# 21 : conv2d_6, <keras.layers.convolutional.Conv2D object at 0x124341f28>
# 22 : concatenate_5, <keras.layers.merge.Concatenate object at 0x1243a17f0>
# 23 : batch_normalization_6, <keras.layers.normalization.BatchNormalization object at 0x1243a1668>
# 24 : activation_6, <keras.layers.core.Activation object at 0x1243a1c88>
# 25 : conv2d_7, <keras.layers.convolutional.Conv2D object at 0x12442fa90>
# 26 : concatenate_6, <keras.layers.merge.Concatenate object at 0x124490c88>
# 27 : batch_normalization_7, <keras.layers.normalization.BatchNormalization object at 0x124490c18>
# 28 : activation_7, <keras.layers.core.Activation object at 0x124490f60>
# 29 : conv2d_8, <keras.layers.convolutional.Conv2D object at 0x124526cf8>
# 30 : concatenate_7, <keras.layers.merge.Concatenate object at 0x1245a6400>
# 31 : concatenate_8, <keras.layers.merge.Concatenate object at 0x1245a68d0>
# 32 : batch_normalization_8, <keras.layers.normalization.BatchNormalization object at 0x1245a66d8>
# 33 : activation_8, <keras.layers.core.Activation object at 0x1245a67b8>
# 34 : conv2d_9, <keras.layers.convolutional.Conv2D object at 0x12463ad68>
# 35 : max_pooling2d_2, <keras.layers.pooling.MaxPooling2D object at 0x124695b70>
# 36 : batch_normalization_9, <keras.layers.normalization.BatchNormalization object at 0x124695a20>
# 37 : activation_9, <keras.layers.core.Activation object at 0x12472ab70>
# 38 : conv2d_10, <keras.layers.convolutional.Conv2D object at 0x12472ae10>
# 39 : concatenate_9, <keras.layers.merge.Concatenate object at 0x124818b70>
# 40 : batch_normalization_10, <keras.layers.normalization.BatchNormalization object at 0x1247a82e8>
# 41 : activation_10, <keras.layers.core.Activation object at 0x1247a86a0>
# 42 : conv2d_11, <keras.layers.convolutional.Conv2D object at 0x12483d128>
# 43 : concatenate_10, <keras.layers.merge.Concatenate object at 0x12489d780>
# 44 : batch_normalization_11, <keras.layers.normalization.BatchNormalization object at 0x12489d5f8>
# 45 : activation_11, <keras.layers.core.Activation object at 0x12489dc18>
# 46 : conv2d_12, <keras.layers.convolutional.Conv2D object at 0x124928a20>
# 47 : concatenate_11, <keras.layers.merge.Concatenate object at 0x12498cfd0>
# 48 : concatenate_12, <keras.layers.merge.Concatenate object at 0x12498ccf8>
# 49 : batch_normalization_12, <keras.layers.normalization.BatchNormalization object at 0x12498cba8>
# 50 : activation_12, <keras.layers.core.Activation object at 0x124a1fe10>
# 51 : conv2d_13, <keras.layers.convolutional.Conv2D object at 0x124a3bc50>
# 52 : max_pooling2d_3, <keras.layers.pooling.MaxPooling2D object at 0x123f67da0>
# 53 : batch_normalization_13, <keras.layers.normalization.BatchNormalization object at 0x123f679e8>
# 54 : activation_13, <keras.layers.core.Activation object at 0x124b23a90>
# 55 : conv2d_14, <keras.layers.convolutional.Conv2D object at 0x124b23a58>
# 56 : concatenate_13, <keras.layers.merge.Concatenate object at 0x124b7cef0>
# 57 : batch_normalization_14, <keras.layers.normalization.BatchNormalization object at 0x124c0b2e8>
# 58 : activation_14, <keras.layers.core.Activation object at 0x124b9e4a8>
# 59 : conv2d_15, <keras.layers.convolutional.Conv2D object at 0x124c30518>
# 60 : concatenate_14, <keras.layers.merge.Concatenate object at 0x124c91860>
# 61 : batch_normalization_15, <keras.layers.normalization.BatchNormalization object at 0x124c916d8>
# 62 : activation_15, <keras.layers.core.Activation object at 0x124c91cf8>
# 63 : conv2d_16, <keras.layers.convolutional.Conv2D object at 0x124d1d828>
# 64 : concatenate_15, <keras.layers.merge.Concatenate object at 0x124d7de80>
# 65 : concatenate_16, <keras.layers.merge.Concatenate object at 0x124d7deb8>
# 66 : batch_normalization_16, <keras.layers.normalization.BatchNormalization object at 0x124da22b0>
# 67 : activation_16, <keras.layers.core.Activation object at 0x124e13f60>
# 68 : conv2d_17, <keras.layers.convolutional.Conv2D object at 0x124e30cf8>
# 69 : max_pooling2d_4, <keras.layers.pooling.MaxPooling2D object at 0x124e92898>
# 70 : batch_normalization_17, <keras.layers.normalization.BatchNormalization object at 0x124e92d30>
# 71 : activation_17, <keras.layers.core.Activation object at 0x124f1e908>
# 72 : conv2d_18, <keras.layers.convolutional.Conv2D object at 0x124f1e860>
# 73 : concatenate_17, <keras.layers.merge.Concatenate object at 0x124f7ef60>
# 74 : batch_normalization_18, <keras.layers.normalization.BatchNormalization object at 0x124f7eeb8>
# 75 : activation_18, <keras.layers.core.Activation object at 0x12500cf98>
# 76 : conv2d_19, <keras.layers.convolutional.Conv2D object at 0x12504ae48>
# 77 : concatenate_18, <keras.layers.merge.Concatenate object at 0x12508f6a0>
# 78 : batch_normalization_19, <keras.layers.normalization.BatchNormalization object at 0x12508f518>
# 79 : activation_19, <keras.layers.core.Activation object at 0x12508fb38>
# 80 : conv2d_20, <keras.layers.convolutional.Conv2D object at 0x12511dbe0>
# 81 : concatenate_19, <keras.layers.merge.Concatenate object at 0x12517ffd0>
# 82 : concatenate_20, <keras.layers.merge.Concatenate object at 0x12517fcf8>
# 83 : batch_normalization_20, <keras.layers.normalization.BatchNormalization object at 0x12517fba8>
# 84 : activation_20, <keras.layers.core.Activation object at 0x125215e10>
# 85 : conv2d_21, <keras.layers.convolutional.Conv2D object at 0x125251e80>
# 86 : max_pooling2d_5, <keras.layers.pooling.MaxPooling2D object at 0x125293710>
# 87 : batch_normalization_21, <keras.layers.normalization.BatchNormalization object at 0x123f10198>
# 88 : activation_21, <keras.layers.core.Activation object at 0x125293ba8>
# 89 : conv2d_22, <keras.layers.convolutional.Conv2D object at 0x125345780>
# 90 : concatenate_21, <keras.layers.merge.Concatenate object at 0x1253a3cf8>
# 91 : batch_normalization_22, <keras.layers.normalization.BatchNormalization object at 0x1253a3c88>
# 92 : activation_22, <keras.layers.core.Activation object at 0x1253a3fd0>
# 93 : conv2d_23, <keras.layers.convolutional.Conv2D object at 0x125438780>
# 94 : concatenate_22, <keras.layers.merge.Concatenate object at 0x1254b44e0>
# 95 : batch_normalization_23, <keras.layers.normalization.BatchNormalization object at 0x1254b4a90>
# 96 : activation_23, <keras.layers.core.Activation object at 0x1254b4978>
# 97 : conv2d_24, <keras.layers.convolutional.Conv2D object at 0x12554ca20>
# 98 : concatenate_23, <keras.layers.merge.Concatenate object at 0x1255a3b38>
# 99 : conv2d_transpose_1, <keras.layers.convolutional.Conv2DTranspose object at 0x1255a3eb8>
# 100 : concatenate_24, <keras.layers.merge.Concatenate object at 0x125657978>
# 101 : batch_normalization_24, <keras.layers.normalization.BatchNormalization object at 0x1256575c0>
# 102 : activation_24, <keras.layers.core.Activation object at 0x125657d68>
# 103 : conv2d_25, <keras.layers.convolutional.Conv2D object at 0x1256bacc0>
# 104 : concatenate_25, <keras.layers.merge.Concatenate object at 0x125717898>
# 105 : batch_normalization_25, <keras.layers.normalization.BatchNormalization object at 0x1256f1e80>
# 106 : activation_25, <keras.layers.core.Activation object at 0x12563bc50>
# 107 : conv2d_26, <keras.layers.convolutional.Conv2D object at 0x1257c0cc0>
# 108 : concatenate_26, <keras.layers.merge.Concatenate object at 0x125806588>
# 109 : batch_normalization_26, <keras.layers.normalization.BatchNormalization object at 0x125806eb8>
# 110 : activation_26, <keras.layers.core.Activation object at 0x125806a20>
# 111 : conv2d_27, <keras.layers.convolutional.Conv2D object at 0x125892f98>
# 112 : concatenate_27, <keras.layers.merge.Concatenate object at 0x1258f5b00>
# 113 : conv2d_transpose_2, <keras.layers.convolutional.Conv2DTranspose object at 0x1258f5fd0>
# 114 : concatenate_28, <keras.layers.merge.Concatenate object at 0x1259a6e80>
# 115 : batch_normalization_27, <keras.layers.normalization.BatchNormalization object at 0x1259a6e10>
# 116 : activation_27, <keras.layers.core.Activation object at 0x1259a6630>
# 117 : conv2d_28, <keras.layers.convolutional.Conv2D object at 0x125a0bc88>
# 118 : concatenate_29, <keras.layers.merge.Concatenate object at 0x125a66208>
# 119 : batch_normalization_28, <keras.layers.normalization.BatchNormalization object at 0x125a42e48>
# 120 : activation_28, <keras.layers.core.Activation object at 0x125a42e80>
# 121 : conv2d_29, <keras.layers.convolutional.Conv2D object at 0x125b0fc88>
# 122 : concatenate_30, <keras.layers.merge.Concatenate object at 0x125b56550>
# 123 : batch_normalization_29, <keras.layers.normalization.BatchNormalization object at 0x125b56b00>
# 124 : activation_29, <keras.layers.core.Activation object at 0x125b569e8>
# 125 : conv2d_30, <keras.layers.convolutional.Conv2D object at 0x125be5a90>
# 126 : concatenate_31, <keras.layers.merge.Concatenate object at 0x125c45ba8>
# 127 : conv2d_transpose_3, <keras.layers.convolutional.Conv2DTranspose object at 0x125c45f98>
# 128 : concatenate_32, <keras.layers.merge.Concatenate object at 0x125cf4e48>
# 129 : batch_normalization_30, <keras.layers.normalization.BatchNormalization object at 0x125cf4dd8>
# 130 : activation_30, <keras.layers.core.Activation object at 0x125cf45f8>
# 131 : conv2d_31, <keras.layers.convolutional.Conv2D object at 0x125d5cc50>
# 132 : concatenate_33, <keras.layers.merge.Concatenate object at 0x125db71d0>
# 133 : batch_normalization_31, <keras.layers.normalization.BatchNormalization object at 0x125d92e10>
# 134 : activation_31, <keras.layers.core.Activation object at 0x125d92e48>
# 135 : conv2d_32, <keras.layers.convolutional.Conv2D object at 0x125e2c7b8>
# 136 : concatenate_34, <keras.layers.merge.Concatenate object at 0x125ea5518>
# 137 : batch_normalization_32, <keras.layers.normalization.BatchNormalization object at 0x125ea5ac8>
# 138 : activation_32, <keras.layers.core.Activation object at 0x125ea59b0>
# 139 : conv2d_33, <keras.layers.convolutional.Conv2D object at 0x125f35a58>
# 140 : concatenate_35, <keras.layers.merge.Concatenate object at 0x125f95b70>
# 141 : conv2d_transpose_4, <keras.layers.convolutional.Conv2DTranspose object at 0x125f95f60>
# 142 : concatenate_36, <keras.layers.merge.Concatenate object at 0x126045e10>
# 143 : batch_normalization_33, <keras.layers.normalization.BatchNormalization object at 0x126045da0>
# 144 : activation_33, <keras.layers.core.Activation object at 0x1260455c0>
# 145 : conv2d_34, <keras.layers.convolutional.Conv2D object at 0x1260a9c18>
# 146 : concatenate_37, <keras.layers.merge.Concatenate object at 0x1260e2cf8>
# 147 : batch_normalization_34, <keras.layers.normalization.BatchNormalization object at 0x1260e2c88>
# 148 : activation_34, <keras.layers.core.Activation object at 0x1260e2fd0>
# 149 : conv2d_35, <keras.layers.convolutional.Conv2D object at 0x126175780>
# 150 : concatenate_38, <keras.layers.merge.Concatenate object at 0x1261f44e0>
# 151 : batch_normalization_35, <keras.layers.normalization.BatchNormalization object at 0x1261f4a90>
# 152 : activation_35, <keras.layers.core.Activation object at 0x1261f4978>
# 153 : conv2d_36, <keras.layers.convolutional.Conv2D object at 0x12628ca20>
# 154 : concatenate_39, <keras.layers.merge.Concatenate object at 0x1262e6b38>
# 155 : conv2d_transpose_5, <keras.layers.convolutional.Conv2DTranspose object at 0x1262e6e80>
# 156 : concatenate_40, <keras.layers.merge.Concatenate object at 0x12637add8>
# 157 : batch_normalization_36, <keras.layers.normalization.BatchNormalization object at 0x12637ad68>
# 158 : activation_36, <keras.layers.core.Activation object at 0x12637a588>
# 159 : conv2d_37, <keras.layers.convolutional.Conv2D object at 0x1263fcb70>
# 160 : concatenate_41, <keras.layers.merge.Concatenate object at 0x126433cc0>
# 161 : batch_normalization_37, <keras.layers.normalization.BatchNormalization object at 0x126433c50>
# 162 : activation_37, <keras.layers.core.Activation object at 0x126433f98>
# 163 : conv2d_38, <keras.layers.convolutional.Conv2D object at 0x1264c9748>
# 164 : concatenate_42, <keras.layers.merge.Concatenate object at 0x1265444a8>
# 165 : batch_normalization_38, <keras.layers.normalization.BatchNormalization object at 0x126544a58>
# 166 : activation_38, <keras.layers.core.Activation object at 0x126544940>
# 167 : conv2d_39, <keras.layers.convolutional.Conv2D object at 0x1265dd470>
# 168 : concatenate_43, <keras.layers.merge.Concatenate object at 0x126636b00>
# 169 : logits, <keras.layers.convolutional.Conv2D object at 0x1255a3e80>
# 170 : softmax, <keras.layers.core.Activation object at 0x126636e80>

# %%
coreml_model.author = 'Kautenja'
coreml_model.license = 'MIT'
coreml_model.short_description = '45 Layers Tiramisu Semantic Segmentation Model trained on CamVid & CityScapes.'
coreml_model.input_description['image'] = 'An input image in RGB order'
coreml_model.output_description['segmentation'] = 'The segmentation map as the Softmax output'

# %%
coreml_model.save('models/Tiramisu45.mlmodel')

# %% [markdown]
# ## Convert Outputs to Float32

# %%
# get the spec from the model
spec = coreml_model.get_spec()
# create a local reference to the Float32 type
Float32 = FeatureTypes_pb2.ArrayFeatureType.FLOAT32
# set the output shape for the segmentation to Float32
spec.description.output[0].type.multiArrayType.dataType = Float32
# visualize the spec to validate changes
spec.description
# Out:
# input {
#   name: "image"
#   shortDescription: "An input image in RGB order"
#   type {
#     imageType {
#       width: 480
#       height: 352
#       colorSpace: RGB
#     }
#   }
# }
# output {
#   name: "segmentation"
#   shortDescription: "The segmentation map as the Softmax output"
#   type {
#     multiArrayType {
#       shape: 12
#       shape: 352
#       shape: 480
#       dataType: FLOAT32
#     }
#   }
# }
# metadata {
#   shortDescription: "45 Layers Tiramisu Semantic Segmentation Model trained on CamVid & CityScapes."
#   author: "Kautenja"
#   license: "MIT"
# }

# %%
coremltools.utils.save_spec(spec, 'models/Tiramisu45.mlmodel')
